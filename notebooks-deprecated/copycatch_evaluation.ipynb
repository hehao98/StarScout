# %%
import pandas as pd

from scripts.analysis import data

repos = data.get_fake_star_repos_all()
repos_dagster = pd.read_csv("data/dagster_test/fake_stars_complex_repos.csv")
stars_dagster = pd.read_csv("data/dagster_test/fake_stars_complex_users.csv")

repos_dagster = repos_dagster[(repos_dagster.n_fake_stars >= 50)]
repo_ids_dagster = set(repos_dagster.repo_id)

print(
    len(repo_ids_dagster),
    len(set(repos.repo_id) & repo_ids_dagster),
    repo_ids_dagster - set(repos.repo_id),
)
perfs = []
for repo_id in set(repos.repo_id) & repo_ids_dagster:
    repo_names = set(repos[repos.repo_id == repo_id].repo_name)
    fakes_copycatch, fakes_dagster = set(), set()
    for repo_name in repo_names:
        df = data.get_stars_from_repo(repo_name)
        if df is None:
            continue
        fakes_copycatch |= set(df[df.low_activity | df.clustered].actor)
        fakes_dagster |= set(
            stars_dagster[
                (stars_dagster.repo_name == repo_name)
                & (stars_dagster.fake_acct != "unknown")
            ].actor
        )
    perfs.append(
        {
            "repo_names": repo_names,
            "n_fakes_copycatch": len(fakes_copycatch),
            "n_fakes_dagster": len(fakes_dagster),
            "n_overlap": len(fakes_copycatch & fakes_dagster),
        }
    )
perfs = pd.DataFrame(perfs)
print("Precision:", perfs.n_overlap.sum() / perfs.n_fakes_copycatch.sum())
print("Recall:", perfs.n_overlap.sum() / perfs.n_fakes_dagster.sum())
perfs
# Out:
# 44 41 {'MDEwOlJlcG9zaXRvcnkyMTM2NDkyMTM=', 'R_kgDOHxZ6lw', 'MDEwOlJlcG9zaXRvcnk4OTkxMzY1NQ=='}
# Precision: 0.7433702689243028
# Recall: 0.21571018262613126
#                                            repo_names  n_fakes_copycatch  \
# 0                                         {ccxt/ccxt}                350
# 1                                     {nocodb/nocodb}                154
# 2                            {h5bp/html5-boilerplate}                238
# 3                                   {mrdoob/three.js}               1179
# 4                                     {tabler/tabler}                118
# 5                               {Joystream/joystream}                676
# 6                          {tailwindlabs/tailwindcss}                440
# 7                                 {electron/electron}                419
# 8                                    {vercel/next.js}               1274
# 9                                   {hydro-dev/Hydro}                609
# 10                        {codigoencasa/bot-whatsapp}                 72
# 11                                   {subquery/subql}               6028
# 12                             {microsoft/playwright}                314
# 13                                 {microsoft/vscode}               2651
# 14                        {fluid-player/fluid-player}                 51
# 15                                      {rails/rails}                155
# 16                                  {apache/superset}                271
# 17                                  {sveltejs/svelte}                381
# 18                                {airbnb/javascript}                962
# 19                            {storybookjs/storybook}                232
# 20                                 {tauri-apps/tauri}                187
# 21                                   {facebook/react}               2784
# 22                    {holochain/holochain-client-js}                177
# 23                            {facebook/react-native}                393
# 24  {30-seconds/30-seconds-of-code, Chalarangelo/3...               1845
# 25                            {aptos-labs/aptos-core}                338
# 26                                 {tatumio/tatum-js}                 73
# 27                            {ant-design/ant-design}               2281
# 28                              {reach-sh/reach-lang}                 56
# 29  {serverless-stack/sst, serverless-stack/server...               3196
# 30                      {pedroslopez/whatsapp-web.js}                161
# 31                                   {twbs/bootstrap}                856
# 32                                      {novuhq/novu}                162
# 33                              {puppeteer/puppeteer}                102
# 34                          {etherspot/etherspot-sdk}                111
# 35                                    {clappr/clappr}                 96
# 36                              {streamr-dev/network}                115
# 37                                  {angular/angular}               1091
# 38                             {discordjs/discord.js}                328
# 39                                     {thx/gogocode}                354
# 40                                        {vuejs/vue}                848
#
#     n_fakes_dagster  n_overlap
# 0               646        350
# 1               551        154
# 2              1393        238
# 3              2685        494
# 4               411        118
# 5              1115        676
# 6              2896        173
# 7              3389        419
# 8              5753        558
# 9               674        609
# 10              123         72
# 11            11050       5859
# 12             1598        314
# 13             6214       1098
# 14               51         51
# 15              528        155
# 16             1107        271
# 17             2592        381
# 18             5920        468
# 19             2765        232
# 20             2309        187
# 21             3024         26
# 22              185        159
# 23             3024        329
# 24            13733       1488
# 25              741        338
# 26              163         73
# 27            10681       2173
# 28               63         56
# 29             2738       2379
# 30              320        161
# 31             4479        722
# 32              947        162
# 33              714        102
# 34              218        111
# 35              320         96
# 36              229        115
# 37             3701        986
# 38             1204        328
# 39              379        354
# 40            10085        848
